# %% [markdown]
# <a href="https://colab.research.google.com/github/mahshidirfan/ML-PROJECT-3/blob/main/PROJECT%203%20(1608022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Experiment name:** Deep Learning using python in real world dataset.

# %% [markdown]
# **ID No.: 1608022**

# %% [markdown]
# **Objective:**
#
# 1. To apply deep learning for a dataset and check different operations.

# %% [markdown]
# **Procedure:**
#
# Here, at first data set was taken. The string type data are changed to numerical values by one hot encoding technique.Then feature and target dataset was selected and separated. After that data set were separated in the trained and tested set. after implementing the classification algorithm,Then accurecy was checked.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np        
import pandas as pd     
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# !wget -O diabetes.csv  https://www.dropbox.com/s/sglreynnyx40pb6/diabetes.csv?dl=0
# Out:
# --2021-12-20 18:38:05--  https://www.dropbox.com/s/sglreynnyx40pb6/diabetes.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/sglreynnyx40pb6/diabetes.csv [following]
# --2021-12-20 18:38:05--  https://www.dropbox.com/s/raw/sglreynnyx40pb6/diabetes.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com/cd/0/inline/BcNqfpIEiFzhPCId9U3LAU8RmNIcnNXdJvc6GfNSf3vcwj8Wk6ilRDMLtn-xgkn_oq_6U0UZQlZAE9Q7abbbQkiXH-C8JUPIi5v54NMGwSp_5xn0MLt3p8uznLWhO2h4UcbNsBzBhzYELDJd8FOsCsj8/file# [following]
# --2021-12-20 18:38:05--  https://uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com/cd/0/inline/BcNqfpIEiFzhPCId9U3LAU8RmNIcnNXdJvc6GfNSf3vcwj8Wk6ilRDMLtn-xgkn_oq_6U0UZQlZAE9Q7abbbQkiXH-C8JUPIi5v54NMGwSp_5xn0MLt3p8uznLWhO2h4UcbNsBzBhzYELDJd8FOsCsj8/file
# Resolving uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com (uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com (uc09c1ac7686a79719047d28dc8f.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23873 (23K) [text/plain]
# Saving to: ‘diabetes.csv’
#
# diabetes.csv        100%[===================>]  23.31K  --.-KB/s    in 0.02s
#
# 2021-12-20 18:38:05 (1.15 MB/s) - ‘diabetes.csv’ saved [23873/23873]

# %%
dataset = pd.read_csv('diabetes.csv')
dataset
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(dataset[pd.isnull(dataset.Pregnancies)])
print(dataset[pd.isnull(dataset.Glucose)])
print(dataset[pd.isnull(dataset.BloodPressure)])
print(dataset[pd.isnull(dataset.SkinThickness)])
print(dataset[pd.isnull(dataset.Insulin)])
print(dataset[pd.isnull(dataset.BMI)])
print(dataset[pd.isnull(dataset.DiabetesPedigreeFunction)])
print(dataset[pd.isnull(dataset.Age)])
print(dataset[pd.isnull(dataset.Outcome)])
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
feature = dataset[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
target = dataset[['Outcome']]

# %%
feature
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# 767            1       93             70  ...  30.4                     0.315   23
#
# [768 rows x 8 columns]

# %%
target
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size = 0.2,random_state = 0)

print(x_train.shape)
print(x_test.shape)
# Out:
# (614, 8)
# (154, 8)

# %%
x_sc = StandardScaler()
x_train = x_sc.fit_transform(x_train)
x_test = x_sc.transform(x_test)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(20, input_dim=8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, 
                    y_train, 
                    epochs=100, 
                    validation_split=0.1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 13ms/step - loss: 0.7855 - accuracy: 0.4656 - val_loss: 0.7151 - val_accuracy: 0.5323
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7371 - accuracy: 0.5399 - val_loss: 0.6744 - val_accuracy: 0.6452
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6998 - accuracy: 0.6033 - val_loss: 0.6412 - val_accuracy: 0.6774
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6703 - accuracy: 0.6268 - val_loss: 0.6153 - val_accuracy: 0.6935
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6459 - accuracy: 0.6232 - val_loss: 0.5877 - val_accuracy: 0.6935
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6218 - accuracy: 0.6322 - val_loss: 0.5634 - val_accuracy: 0.6935
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.6395 - val_loss: 0.5415 - val_accuracy: 0.6935
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5817 - accuracy: 0.6649 - val_loss: 0.5257 - val_accuracy: 0.7258
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5624 - accuracy: 0.6938 - val_loss: 0.5078 - val_accuracy: 0.7581
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.7120 - val_loss: 0.4908 - val_accuracy: 0.7742
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5307 - accuracy: 0.7228 - val_loss: 0.4778 - val_accuracy: 0.8065
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5188 - accuracy: 0.7482 - val_loss: 0.4695 - val_accuracy: 0.8065
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.7518 - val_loss: 0.4640 - val_accuracy: 0.8387
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4986 - accuracy: 0.7500 - val_loss: 0.4630 - val_accuracy: 0.8226
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.7591 - val_loss: 0.4612 - val_accuracy: 0.8065
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.7609 - val_loss: 0.4614 - val_accuracy: 0.7903
# Epoch 17/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4792 - accuracy: 0.7681 - val_loss: 0.4613 - val_accuracy: 0.8065
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4747 - accuracy: 0.7699 - val_loss: 0.4628 - val_accuracy: 0.7903
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.7681 - val_loss: 0.4647 - val_accuracy: 0.7742
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.7627 - val_loss: 0.4665 - val_accuracy: 0.7903
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.7681 - val_loss: 0.4692 - val_accuracy: 0.7903
# Epoch 22/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4615 - accuracy: 0.7736 - val_loss: 0.4711 - val_accuracy: 0.7903
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4592 - accuracy: 0.7681 - val_loss: 0.4744 - val_accuracy: 0.7903
# Epoch 24/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.7699 - val_loss: 0.4755 - val_accuracy: 0.7903
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4545 - accuracy: 0.7754 - val_loss: 0.4780 - val_accuracy: 0.7903
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7754 - val_loss: 0.4785 - val_accuracy: 0.7903
# Epoch 27/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.7790 - val_loss: 0.4798 - val_accuracy: 0.7903
# Epoch 28/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.
100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8152 - val_loss: 0.5213 - val_accuracy: 0.7581
# Epoch 70/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4030 - accuracy: 0.8116 - val_loss: 0.5257 - val_accuracy: 0.7742
# Epoch 71/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4014 - accuracy: 0.8134 - val_loss: 0.5262 - val_accuracy: 0.7742
# Epoch 72/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8134 - val_loss: 0.5261 - val_accuracy: 0.7742
# Epoch 73/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3999 - accuracy: 0.8188 - val_loss: 0.5266 - val_accuracy: 0.7742
# Epoch 74/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3987 - accuracy: 0.8188 - val_loss: 0.5286 - val_accuracy: 0.7742
# Epoch 75/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.8188 - val_loss: 0.5326 - val_accuracy: 0.7742
# Epoch 76/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8243 - val_loss: 0.5310 - val_accuracy: 0.7742
# Epoch 77/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8243 - val_loss: 0.5297 - val_accuracy: 0.7742
# Epoch 78/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.8152 - val_loss: 0.5290 - val_accuracy: 0.7742
# Epoch 79/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3953 - accuracy: 0.8188 - val_loss: 0.5300 - val_accuracy: 0.7903
# Epoch 80/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3935 - accuracy: 0.8170 - val_loss: 0.5293 - val_accuracy: 0.7903
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.8207 - val_loss: 0.5313 - val_accuracy: 0.7903
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.8170 - val_loss: 0.5333 - val_accuracy: 0.7581
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3906 - accuracy: 0.8225 - val_loss: 0.5361 - val_accuracy: 0.7903
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8170 - val_loss: 0.5357 - val_accuracy: 0.7903
# Epoch 85/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8207 - val_loss: 0.5373 - val_accuracy: 0.7903
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8207 - val_loss: 0.5401 - val_accuracy: 0.7903
# Epoch 87/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.8207 - val_loss: 0.5376 - val_accuracy: 0.7903
# Epoch 88/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8243 - val_loss: 0.5388 - val_accuracy: 0.7903
# Epoch 89/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3848 - accuracy: 0.8261 - val_loss: 0.5385 - val_accuracy: 0.7903
# Epoch 90/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3845 - accuracy: 0.8243 - val_loss: 0.5412 - val_accuracy: 0.7903
# Epoch 91/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3838 - accuracy: 0.8261 - val_loss: 0.5393 - val_accuracy: 0.7903
# Epoch 92/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3818 - accuracy: 0.8261 - val_loss: 0.5393 - val_accuracy: 0.7903
# Epoch 93/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3818 - accuracy: 0.8297 - val_loss: 0.5432 - val_accuracy: 0.7903
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8297 - val_loss: 0.5411 - val_accuracy: 0.7903
# Epoch 95/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8225 - val_loss: 0.5388 - val_accuracy: 0.8065
# Epoch 96/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.8333 - val_loss: 0.5388 - val_accuracy: 0.8226
# Epoch 97/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3781 - accuracy: 0.8315 - val_loss: 0.5430 - val_accuracy: 0.7903
# Epoch 98/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.8152 - val_loss: 0.5490 - val_accuracy: 0.8065
# Epoch 99/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.8315 - val_loss: 0.5465 - val_accuracy: 0.8065
# Epoch 100/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.8297 - val_loss: 0.5512 - val_accuracy: 0.8065

# %%
history_df = pd.DataFrame(history.history)
plt.plot(history_df['loss'], label='loss')
plt.plot(history_df['val_loss'], label='val_loss')

plt.legend()

# %%
plt.plot(history_df['accuracy'], label='acc')
plt.plot(history_df['val_accuracy'], label='val_acc')

plt.legend()

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(x_test)
y_pred = y_pred > 0.5
pred = y_pred.astype('uint8')
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       107
#            1       0.66      0.62      0.64        47
#
#     accuracy                           0.79       154
#    macro avg       0.75      0.74      0.74       154
# weighted avg       0.78      0.79      0.78       154

# %% [markdown]
# **Final Results:**
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       107
#            1       0.64      0.60      0.62        47
#
#     accuracy
#                                0.77       154
#    macro avg
#
#           0.73      0.72      0.73       154
# weighted avg
#
#        0.77      0.77      0.77       154

# %% [markdown]
# **Conclusion:**
#
# Here, all the operations were carried out such as one hot encoding, fit transform, train and test set separation etc. After the machine learning model was built various performance parameters such as precision, recall, f1-score,support, accuracy, weighted avg.and macro avg. were calculated to measure the efficiency of the system.
